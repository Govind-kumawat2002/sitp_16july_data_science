# %%
# pip install seaborn 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data =sns.load_dataset('tips') ### load dataset from seaborn

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.title("made by matplotlib ")
plt.plot(data['total_bill'])

plt.show()

# %%
plt.title("made by seaborn ")
sns.lineplot(data['total_bill'])
plt.show()

# %%
plt.title("This is scatter plot ")
sns.scatterplot(x = 'total_bill', y = 'tip', data= data )
plt.show()

# %%
plt.title("made by seaborn ")
sns.histplot(data['total_bill'])
plt.show()

# %%
plt.title("made by matplotlib ")
plt.hist(data['total_bill'])
plt.show()

# %%
plt.title("This is a kdeplot")
sns.kdeplot(data['total_bill'])
plt.show()

# %%
# catplot 
# relplot

# %%
# plt.title("this is relplot ")
sns.relplot(x = 'total_bill', y = 'tip', data=data)
plt.show()

# %%
data['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'time', data=data )
plt.show()

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'time', style='smoker', data=data)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'time', style='smoker', kind='scatter', col='smoker', data=data)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'time', style='smoker', kind='scatter', row='smoker', data=data)

# %%
data['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.relplot(x = 'total_bill', y ='tip', hue='time', kind='scatter', col='day', data=data)

# %%
sns.relplot(x = 'total_bill', y = 'tip', data=data)
plt.title("total_bill vs tip")
plt.xlabel("total_bill",fontsize = 20, color = 'red')
plt.ylabel("tip",fontsize = 20, color = 'red')
plt.show()

# %%
#####  catplot 
sns.catplot(x = 'day',  y = 'total_bill', data=data,kind='swarm')
plt.show()

# %%
sns.catplot(x = 'day',  y = 'total_bill', data=data,kind='strip')
plt.show()

# %%
sns.catplot(x = 'day',  y = 'total_bill', data=data,kind='violin')
plt.show()

# %%
sns.catplot(x = 'day',  y = 'total_bill', data=data,kind='boxen')
plt.show()

# %%
sns.catplot(x = 'day',  y = 'total_bill', data=data,kind='box')
plt.show()

# %%
sns.catplot(x = 'day',  y = 'total_bill', data=data,kind='bar')
plt.show()

# %%
sns.countplot(data['day'])
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
sns.boxplot(data['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>
